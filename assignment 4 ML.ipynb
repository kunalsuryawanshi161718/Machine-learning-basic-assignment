# %% [markdown]
# ## 1. What are the key tasks involved in getting ready to work with machine learning modeling?
#
# Ans: -
#
# Task 1
#
# Collect the data: The quality and quantity of data is very important in term of collecting the data that you are going to feed in your machine.
#
# Task 2:
#
# Prepare the data: - visualize the data and balance the features if there is any correlation between features, we can filter it and we can reduce the dimension.
#
# Task 3:
#
# Choose the modal:
#
# Choosing the correct model for the project. We can use algorithms of classification, prediction, linear regression, clustering, i.e. k-means or K-Nearest Neighbour, Deep Learning, i.e Neural Networks, Bayesian, etc.
#
# Task 4:
#
# Train your machine model:
#
# You will need to train the datasets to run smoothly and see an incremental improvement in the prediction rate.
#
# Task 5: Evaluation:
#
# Check out the accuracy of the modal
#
# Task 6:
#
# Parameter Tuning:
#
# According to the accuracy we can adjust overfitting and underfitting curve or we can set the learning rate parameter.
#
# ## 2. What are the different forms of data used in machine learning? Give a specific example for each of them.
#
# Ans: - Data used in machine learning are: -
#
# Numerical Data: - any data where data points are exact numbers.e.g. continuous(height,weight,salary,temp) and discreat(language,number of student)
#
# Categorical Data: - data represents characteristics, such as a hockey player’s position, team, hometown.
#
# Time Series Data: -
#
# data is a sequence of numbers collected at regular intervals over some period of time. For example, we might measure the average number of home sales for many years.
#
#
# ## 3. Distinguish:
#
#            1. Numeric vs. categorical attributes: - Numerical attributes are represent in numbers such as measurements they are continues and discreet in nature for example weight, height, number of students in class etc. while in categorical the object belongs to certain class or it carry a particular characteristic for example player’s position, team, hometown.
#
#             2. Feature selection vs. dimensionality reduction: - Feature selection and dimensionality reduction both methods are used for reducing the number of features in a dataset, there is an important difference.
#
# Feature selection is simply selecting and excluding given features without changing them.
# Dimensionality reduction transforms features into a lower dimension.
#
# ## 4. Make quick notes on any two of the following:
#
#             1. The histogram: - The histogram is the analysis graph tool which is used when the data is numerical data type. It is used to show frequency distribution values. Example: Analysing whether a process can meet the customer’s requirements
#
#              2. Use a scatter plot: - The scatter diagram graphs pairs of numerical data, with one variable on each axis, to look for a relationship between them. If the variables are correlated, the points will fall along a line or curve. It is used when you have paired numerical data.
#
# ## 5. Why is it necessary to investigate data? Is there a discrepancy in how qualitative and quantitative data are explored?
#
# Ans: - Collecting and analysing data helps you see whether your intervention brought about the desired results. Qualitative data can sometimes tell you things that quantitative data can’t.  It may reveal why certain methods are working or not working, whether part of what you’re doing conflicts with participants’ culture, what participants see as important, etc.
#
# ## 6. What are the various histogram shapes? What exactly are ‘bins'?
#
# •	Normal Distribution
#
# •	Skewed Distribution
#
# •	Double-Peaked or Bimodal
#
# •	Plateau or Multimodal Distribution
#
# •	Edge Peak Distribution
#
# •	Comb Distribution
#
# •	Truncated or Heart-Cut Distribution
#
# •	Dog Food Distribution
#
# Bins are also sometimes called "intervals", "classes", or "buckets".
#
#
#
#
#
#
# ## 7. How do we deal with data outliers?
#
# Ans: - Trimming/removing the outlier: - In this technique, we remove the outliers from the dataset. Although it is not a good practice to follow.
#
# Quantile based flooring and capping: - In this technique, the outlier is capped at a certain value above the 90th percentile value or floored at a factor below the 10th percentile value.
#
# Mean/Median imputation: - As the mean value is highly influenced by the outliers, it is advised to replace the outliers with the median value.
#
# ## 8. What are the various central inclination measures? Why does mean vary too much from median in certain data sets?
#
# Ans: - numeric averages - Arithmetic mean, geometric mean, harmonic mean
#
#            positional averages - median and mode
#
#            when there are outliers mean very too much from median in certain dataset
#
# ## 9. Describe how a scatter plot can be used to investigate bivariate relationships. Is it possible to find outliers using a scatter plot?
#
# Ans: - A scatter plot can be used to investigate correlation between two features by observing the data points weather they are lying on straight line or not. Similar in case of other functions also like trigonometric or quadratic. And we can also find the outliers using scattered plot also.
#
# ## 10. Describe how cross-tabs can be used to figure out how two variables are related.
#
# Ans: - Cross tabs or cross tabulation are only used to find relations between two categorical variables where one categorical variable value would be giving row data and the other variable would give column data. Several tests like the chi square test can help find relations based on the cross tab.
